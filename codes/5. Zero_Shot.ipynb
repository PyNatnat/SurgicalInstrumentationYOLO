# %%
# 1. Install the official YOLO library (Ultralytics) to enable the '!yolo' command
# !pip install ultralytics -q

# %%
# 2. Mount Google Drive to access the weights and video
from google.colab import drive
drive.mount('/content/drive')

# %%
# 3. Execute zero-shot inference using the trained YOLOv11s model
# !yolo task=detect mode=predict model="/content/drive/MyDrive/best.pt" source="/content/drive/MyDrive/youtube.test.mp4" conf=0.5 save=True
